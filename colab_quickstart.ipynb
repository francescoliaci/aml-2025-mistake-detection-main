# %% [markdown]
# # Colab Quickstart

# %%
# !git clone --recursive https://github.com/francescoliaci/aml-2025-mistake-detection-main code

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# TODO: update the paths below with your own

# !mkdir code/data
# !unzip "/content/drive/MyDrive/AMLproject/omnivore.zip" -d code/

# %%
mv code/omnivore code/data/

# %%
mkdir -p code/data/video

# %%
mv code/data/omnivore code/data/video/

# %%
# !pip install torcheval

# !pip install loguru wandb torcheval

# %%
# %%bash
#
# cd code
# python train_er.py \
#   --variant LSTM \
#   --backbone omnivore \
#   --split step \
